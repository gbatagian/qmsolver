# %%
from qmsolver.tise import FDSolver
from qmsolver.potentials import DoubleSquareWellPotential

# %%
dw_solver = FDSolver(steps=2_000, x_min=-5, x_max=5, n_lowest=12)
dw_potential = DoubleSquareWellPotential(
    x_grid=dw_solver.x_grid,
    well_1_center=-2,
    well_1_depth=25,
    well_1_width=2,
    well_2_center=2,
    well_2_depth=25,
    well_2_width=2,
)
dw_solver.potential_generator = dw_potential
dw_solver.solve()
dw_solver.output()
dw_solver.plot()
# Out:
# ****************************************
#
# -> 12 lowest energy states:
#
#       🔒   E(0)  =  -24.0554385810  (bound)
#       🔒   E(1)  =  -24.0554381511  (bound)
#       🔒   E(2)  =  -21.2408992115  (bound)
#       🔒   E(3)  =  -21.2408955280  (bound)
#       🔒   E(4)  =  -16.6240625100  (bound)
#       🔒   E(5)  =  -16.6240303993  (bound)
#       🔒   E(6)  =  -10.3703744578  (bound)
#       🔒   E(7)  =  -10.3698928087  (bound)
#       🔒   E(8)  =   -3.0111303637  (bound)
#       🔒   E(9)  =   -2.9883678904  (bound)
#       🌊   E(10) =    0.9650591168  (free)
#       🌊   E(11) =    1.1728921361  (free)
#
# ****************************************

# %%
dw_solver = FDSolver(steps=2_000, x_min=-5, x_max=5, n_lowest=10)
dw_potential = DoubleSquareWellPotential(
    x_grid=dw_solver.x_grid,
    well_1_center=-2,
    well_1_depth=25,
    well_1_width=2,
    well_2_center=2,
    well_2_depth=20,
    well_2_width=1,
)
dw_solver.potential_generator = dw_potential
dw_solver.solve()
dw_solver.output()
dw_solver.plot()
# Out:
# ****************************************
#
# -> 10 lowest energy states:
#
#       🔒   E(0)  =  -24.0554383661  (bound)
#       🔒   E(1)  =  -21.2408973698  (bound)
#       🔒   E(2)  =  -17.1878473437  (bound)
#       🔒   E(3)  =  -16.6240464547  (bound)
#       🔒   E(4)  =  -10.3701336639  (bound)
#       🔒   E(5)  =   -9.2564508259  (bound)
#       🔒   E(6)  =   -2.9998956483  (bound)
#       🌊   E(7)  =    0.1098018980  (free)
#       🌊   E(8)  =    0.7598746647  (free)
#       🌊   E(9)  =    1.1564670784  (free)
#
# ****************************************
