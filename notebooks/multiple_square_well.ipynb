# %%
from qmsolver.tise import FDSolver
from qmsolver.potentials import MultipleSquareWellPotential

# %%
mw_solver = FDSolver(steps=4_000, x_min=-16, x_max=16, n_lowest=22)
mw_potential = MultipleSquareWellPotential(
    x_grid=mw_solver.x_grid,
    well_depth=15,
    well_width=1.0,
    separation=2.5,
    num_wells=10,
)
mw_solver.potential_generator = mw_potential
mw_solver.solve()
mw_solver.output()
mw_solver.plot()
# Out:
# ****************************************
#
# -> 22 lowest energy states:
#
#       🔒   E(0)  =  -12.3986550425  (bound)
#       🔒   E(1)  =  -12.3984124077  (bound)
#       🔒   E(2)  =  -12.3980314816  (bound)
#       🔒   E(3)  =  -12.3975874239  (bound)
#       🔒   E(4)  =  -12.3973465560  (bound)
#       🔒   E(5)  =  -12.3970806740  (bound)
#       🔒   E(6)  =  -12.3966353429  (bound)
#       🔒   E(7)  =  -12.3962512213  (bound)
#       🔒   E(8)  =  -12.3960056929  (bound)
#       🔒   E(9)  =  -12.3673368690  (bound)
#       🔒   E(10) =   -5.3135452752  (bound)
#       🔒   E(11) =   -5.3070780568  (bound)
#       🔒   E(12) =   -5.2969108052  (bound)
#       🔒   E(13) =   -5.2849529658  (bound)
#       🔒   E(14) =   -5.2799075029  (bound)
#       🔒   E(15) =   -5.2699424941  (bound)
#       🔒   E(16) =   -5.2571569727  (bound)
#       🔒   E(17) =   -5.2459212785  (bound)
#       🔒   E(18) =   -5.2384932278  (bound)
#       🔒   E(19) =   -5.1713892613  (bound)
#       🌊   E(20) =    0.2037293056  (free)
#       🌊   E(21) =    0.3181431985  (free)
#
# ****************************************
